# %% [markdown]
# # Módulo 06 Tarefa 2

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('b1abb33c4f.csv', delimiter=',', encoding='latin1')

# %% [markdown]
# ####  1) Na base do SINASC do DataSUS, faça um boxplot da idade da mãe.

# %%
data.boxplot(column='IDADEMAE')
plt.title('Boxplot da Idade da Mãe')
plt.ylabel('Idade da Mãe')
plt.show()

# %% [markdown]
# ####  2) Faça um boxplot do peso do bebê

# %%
data.boxplot(column='PESO')
plt.title('Boxplot do Peso do Bebê')
plt.ylabel('Peso do Bebê (gramas)')
plt.show()

# %% [markdown]
# ####  3) Faça um histograma da idade da mãe

# %%
data['IDADEMAE'].hist(bins=20)
plt.title('Histograma da Idade da Mãe')
plt.xlabel('Idade da Mãe')
plt.ylabel('Frequência')
plt.show()

# %% [markdown]
# #### 4) Faça um histograma do peso do bebê

# %%
data['PESO'].hist(bins=20)
plt.title('Histograma do Peso do Bebê')
plt.xlabel('Peso do Bebê (gramas)')
plt.ylabel('Frequência')
plt.show()
